# %% [markdown]
# <a href="https://colab.research.google.com/github/tayyabijaz/DataScience/blob/master/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.linspace(0, 2*np.pi, 50)
x = np.sin(t)
y = np.cos(t)
# Now create a figure
plt.figure()
# and plot x inside it
plt.plot(x)

# %%
# Now create a new figure
plt.figure()
# and plot y inside it...
plt.plot(y)
# Add a title
plt.title("Cos")
# Out:
# Text(0.5, 1.0, 'Cos')

# %%
y1 = np.sin(x)
y2 = np.sin(2*x)
plt.figure() # Create figure
plt.plot(y1)
plt.plot(x, y1)

# red dot-dash circle
plt.plot(x, y1, 'r')

# red marker only circle
plt.plot(x, y1, 'r-o')

# clear figure then plot 2 curves
plt.clf()
plt.plot(x, y1, 'g-o', x, y2, 'b-+')
plt.legend(['sin(x)','sin(2x)'])

# %%
N = 50 # no. of points
x = np.linspace(0, 10, N)
#print(x)
from numpy.random import rand
e = rand(N)*5.0 # noise
y1 = x + e
areas = rand(N)*300
plt.scatter(x, y1, s=areas)
colors = rand(N)
plt.scatter(x, y1, s=areas,c=colors)
plt.colorbar()
plt.title("Random scatter")
# Out:
# Text(0.5, 1.0, 'Random scatter')

# %%
e1 = rand(100)
e2 = rand(100)*2
e3 = rand(100)*50
e4 = rand(100)*100
corrmatrix = np.corrcoef([e1, e2, e3, e4])
print(corrmatrix)
# Plot corr matrix as image
plt.imshow(corrmatrix, cmap='GnBu')
plt.colorbar()
# Out:
# [[ 1.          0.12105758  0.14776061 -0.05680918]
#  [ 0.12105758  1.         -0.19209439 -0.03989644]
#  [ 0.14776061 -0.19209439  1.         -0.01991717]
#  [-0.05680918 -0.03989644 -0.01991717  1.        ]]

# %%
t = np.linspace(0, 2*np.pi)
x = np.sin(t)
y = np.cos(t)
# To divide the plotting area
plt.subplot(2, 1, 1)
plt.plot(x)
# Now activate a new plot
# area.
plt.subplot(2, 1, 2)
plt.plot(y)

# %%
# Create array of data
from numpy.random import randint
data = randint(10000, size=(10,1000))
# Approx norm distribution
x = np.sum(data, axis=0)
# Set up for stacked plots
plt.subplot(2,1,1)
plt.hist(x, color='r')
# Plot cumulative dist
plt.subplot(2,1,2)
plt.hist(x, cumulative=True)
# Out:
# (array([   4.,   22.,   97.,  241.,  457.,  672.,  851.,  949.,  994.,
#         1000.]),
#  array([21013. , 26570.2, 32127.4, 37684.6, 43241.8, 48799. , 54356.2,
#         59913.4, 65470.6, 71027.8, 76585. ]),
#  <a list of 10 Patch objects>)

# %%
# Add labels in plot command.
plt.plot(np.sin(t), label='sin')
plt.plot(np.cos(t), label='cos')
plt.legend()

# %%
plt.plot(t, np.sin(t))
plt.xlabel('radians')
# Keywords set text properties.
plt.ylabel('amplitude',fontsize='large')
plt.title('Sin(x)')
# Out:
# Text(0.5, 1.0, 'Sin(x)')

# %%
import numpy as np

# Simple array creation
a = np.array([0, 1, 2, 3, 4, 5])
# Checking the type and type of elements
print(type(a))
print(a.dtype)
print(a)
# Out:
# [0 1 2 3 4 5]

# %%
# Checking the type and type of elements
print(type(a))
print(a.dtype)
# Out:
# <class 'numpy.ndarray'>
# int64

# %%
# Check dimensions and shape
print(a.ndim)
print(a.shape)
# Out:
# 1
# (6,)

# %%
# Check Bytes per element and Bytes of memory use
print(a.itemsize)
print(a.nbytes)
# Out:
# 8
# 48

# %%
a = np.array([1, 2, 3, 4])
b = np.array([2, 3, 4, 5])

print(a*b)
print(a**b)
print(a+b)
print(a/b)
# Out:
# [ 2  6 12 20]
# [   1    8   81 1024]
# [3 5 7 9]
# [0.5        0.66666667 0.75       0.8       ]

# %%
# Setting array elements
print(a[0])
a[0] = 10
print(a[0])
print(a)
# Out:
# 1
# 10
# [10  2  3  4]

# %%
# Multi-dimensional array

a = np.array([[ 0, 1, 2, 3],
              [10,11,12,13]])
print(a)
# Out:
# [[ 0  1  2  3]
#  [10 11 12 13]]

# %%
print(a.shape)
print(a.size)
print(a.ndim)
# Out:
# (2, 4)
# 8
# 2

# %%
# Get and set elements in Multi-dimensional array
print(a[1, 3])
a[1, 3] = -1
print(a[1, 3])
# Out:
# 13
# -1

# %%
print(a[1])
# Out:
# [10 11 12 -1]

# %%
# Slicing array
print(a)

# print all row and 3rd column
print(a[:,2])

# print first row and all column 
print(a[0,:])

# negative indices work also
print(a)
print(a[:,:-2])
# Out:
# [[ 0  1  2  3]
#  [10 11 12 -1]]
# [ 2 12]
# [0 1 2 3]
# [[ 0  1  2  3]
#  [10 11 12 -1]]
# [[ 0  1]
#  [10 11]]

# %% [markdown]
# **Questions of LAB 1**

# %%
a = np.array([[1, 2],[1, 2],[1, 2],[1, 2]])
print(a)
# Out:
# [[1 2]
#  [1 2]
#  [1 2]
#  [1 2]]

# %%
a = np.array([7,2,6,4,5,6,7,8,9,10])
# Sort in ascending order
sorted_array = np.sort(a)
# [1, 2, 3, 4, 5, 6, 7]

# Reverse the sorted array
reverse_array = sorted_array[::-1]
print(sorted_array)
print(reverse_array)
# Out:
# [ 2  4  5  6  6  7  7  8  9 10]
# [10  9  8  7  7  6  6  5  4  2]

# %%
a = np.array([7,2,6,4,5,6,7,8,9,10])
b = np.reshape(a, (-1, 2))
print(b)
# Out:
# [[ 7  2]
#  [ 6  4]
#  [ 5  6]
#  [ 7  8]
#  [ 9 10]]

# %%
a = np.array([7,2,6,4,5,6,7,8,9,10])
b = np.array([7,2,6,4,5,6,7,8,9,11])
c = np.stack((a, b), axis = 1) 
print(c)
# Out:
# [[ 7  7]
#  [ 2  2]
#  [ 6  6]
#  [ 4  4]
#  [ 5  5]
#  [ 6  6]
#  [ 7  7]
#  [ 8  8]
#  [ 9  9]
#  [10 11]]

# %%
a = np.array([7,2,6,4,5,6,7,8,9,10])
b = np.array([7,2,6,4,5,6,7,8,9])
print(np.intersect1d(a, b))
# Out:
# [2 4 5 6 7 8 9]

# %%
a = np.array([[7,2,6,4,5],[7,2,6,4,5],[7,2,6,4,5],[7,2,6,4,5],[7,2,6,4,5]])

print(np.amin(a, axis=0))
print(np.amin(a, axis=1))
print(np.amax(a, axis=0))
print(np.amax(a, axis=1))
# Out:
# [7 2 6 4 5]
# [2 2 2 2 2]
# [7 2 6 4 5]
# [7 7 7 7 7]

# %%
a = np.random.randint(1, 30, 100, dtype='l')
print(np.mean(a))
print(np.median(a))
print(np.std(a))
# Out:
# 14.56
# 15.0
# 8.16862289495604

# %%
a = np.random.randint(6, size=(5, 5))
row_sums = a.sum(axis=1)
new_matrix = a / row_sums[:, np.newaxis]

print(new_matrix)
# Out:
# [[0.35714286 0.14285714 0.07142857 0.07142857 0.35714286]
#  [0.23076923 0.         0.38461538 0.30769231 0.07692308]
#  [0.18181818 0.09090909 0.45454545 0.18181818 0.09090909]
#  [0.23076923 0.30769231 0.30769231 0.15384615 0.        ]
#  [0.11111111 0.11111111 0.27777778 0.22222222 0.27777778]]

# %%
a = np.random.randint(6, size=(4,4,3))
b = np.random.randint(6, size=(4, 4))

a * b[:,:,None]
# Out:
# array([[[ 9, 15, 15],
#         [ 5,  2,  3],
#         [12,  4,  4],
#         [20,  8,  8]],
#
#        [[ 5,  3,  2],
#         [ 5,  4,  1],
#         [20,  4,  0],
#         [ 0,  0,  0]],
#
#        [[ 3,  4,  4],
#         [ 0,  0,  0],
#         [ 5, 25, 25],
#         [ 3,  3, 12]],
#
#        [[ 3, 12, 12],
#         [16, 20,  0],
#         [10,  5,  0],
#         [ 0,  0,  0]]])
